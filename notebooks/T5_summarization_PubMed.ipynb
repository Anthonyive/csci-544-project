# %%
from google.colab import drive
import os
import sys
drive.mount('/content/gdrive/', force_remount=True)
outdir = "/content/gdrive/MyDrive/project"
assert not os.system("mkdir -p "+outdir)
sys.path.insert(0, outdir)
# Out:
# Mounted at /content/gdrive/

# %%
result = "/content/gdrive/MyDrive/result"
import transformers
from datasets import load_dataset, load_metric, load_from_disk
import datasets
import random
import pandas as pd
from IPython.display import display, HTML
from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
import nltk
import numpy as np
from transformers import AutoTokenizer
nltk.download('punkt', download_dir=result)
nltk.data.path.append(result)
raw_datasets = load_dataset("ccdv/pubmed-summarization", cache_dir=result)
metric = load_metric("rouge")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /content/gdrive/MyDrive/result...
# [nltk_data]   Package punkt is already up-to-date!
# Downloading:   0%|          | 0.00/4.88k [00:00<?, ?B/s]
# No config specified, defaulting to: pub_med_summarization_dataset/document
# Reusing dataset pub_med_summarization_dataset (/content/gdrive/MyDrive/result/ccdv___pub_med_summarization_dataset/document/1.0.0/5792402f4d618f2f4e81ee177769870f365599daa729652338bac579552fec30)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/2.17k [00:00<?, ?B/s]

# %%
def show_random_elements(dataset, num_examples=5):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    for column, typ in dataset.features.items():
        if isinstance(typ, datasets.ClassLabel):
            df[column] = df[column].transform(lambda i: typ.names[i])
    display(HTML(df.to_html()))

def preprocess_function(examples, max_input_length=4096, max_target_length = 256):
    inputs = ["summarize: " + doc for doc in examples["article"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["abstract"], max_length=max_target_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]
    
    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    # Extract a few results
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# raw_datasets["train"][0]
# show_random_elements(raw_datasets["train"])
# fake_preds = ["hello there", "general kenobi"]
# fake_labels = ["hello there", "general kenobi"]
# metric.compute(predictions=fake_preds, references=fake_labels)
# tokenized_datasets = raw_datasets.map(preprocess_function, batched=True)
# tokenized_datasets.save_to_disk(result+"/tokenized_datasets")
#["t5-small", "t5-base", "t5-larg", "t5-3b", "t5-11b"]:

# %%
model_checkpoint = "t5-base"
#model_checkpoint = result+"/new-t5base-finetuned-pubmed/checkpoint-13000"
model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint)

tokenized_datasets = load_from_disk(result+"/tokenized_datasets")
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, cache_dir=result)
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)
# Out:
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]

# %%
args = Seq2SeqTrainingArguments(
    f"{result}/t5base-finetuned-pubmed",
    evaluation_strategy = "steps",
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    #weight_decay=0.01,
    eval_steps = 5000,
    save_total_limit=2,
    num_train_epochs=1,
    predict_with_generate=True,
    save_steps = 1000,
    max_steps=10000,
    fp16=True)

trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# max_steps is given, it will override any value given in num_train_epochs
# Using amp fp16 backend

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: abstract, article.
# ***** Running training *****
#   Num examples = 119924
#   Num Epochs = 1
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 10000
#     <div>
#
#       <progress value='10000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10000/10000 2:59:46, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5000</td>
#       <td>1.857300</td>
#       <td>1.632931</td>
#       <td>13.702500</td>
#       <td>4.997100</td>
#       <td>12.398600</td>
#       <td>12.910400</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>1.844500</td>
#       <td>1.632931</td>
#       <td>13.702500</td>
#       <td>4.997100</td>
#       <td>12.398600</td>
#       <td>12.910400</td>
#       <td>19.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-1000
# Configuration saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-1000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-1000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-1000/spiece.model
# Saving model checkpoint to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-2000
# Configuration saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-2000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-2000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-2000/spiece.model
# Saving model checkpoint to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-3000
# Configuration saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-3000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-3000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-3000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-4000
# Configuration saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-4000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-4000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-4000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-2000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: abstract, article.
# ***** Running Evaluation *****
#   Num examples = 6633
#   Batch size = 4
# Saving model checkpoint to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-5000
# Configuration saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-5000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-5000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-5000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-6000
# Configuration saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-6000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-6000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-6000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-7000
# Configuration saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-7000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-7000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-7000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-8000
# Configuration saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-8000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-8000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-8000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-9000
# Configuration saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-9000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-9000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-9000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-7000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: abstract, article.
# ***** Running Evaluation *****
#   Num examples = 6633
#   Batch size = 4
# Saving model checkpoint to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-10000
# Configuration saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-10000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-10000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-10000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/t5base-finetuned-pubmed/checkpoint-8000] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=10000, training_loss=1.842577880859375, metrics={'train_runtime': 10787.8071, 'train_samples_per_second': 3.708, 'train_steps_per_second': 0.927, 'total_flos': 5.48062101504e+16, 'train_loss': 1.842577880859375, 'epoch': 0.33})

# %%
trainer.train(resume_from_checkpoint=result+"/new-t5base-finetuned-pubmed/checkpoint-11500")
# Out:
# Loading model from /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-11500).
# The following columns in the training set  don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, abstract.
# ***** Running training *****
#   Num examples = 119924
#   Num Epochs = 1
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 29981
#   Continuing training from checkpoint, will skip to saved global_step
#   Continuing training from epoch 0
#   Continuing training from global step 11500
#   Will skip the first 0 epochs then the first 11500 batches in the first epoch. If this takes a lot of time, you can add the `--ignore_data_skip` flag to your launch command, but you will resume the training on data already seen by your model.
#   0%|          | 0/11500 [00:00<?, ?it/s]
#     <div>
#
#       <progress value='29981' max='29981' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [29981/29981 4:44:21, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-12000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-12000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-12000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-12000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-10500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-12500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-12500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-12500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-12500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-11000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-13000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-13000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-13000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-13000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-11500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-13500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-13500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-13500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-13500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-12000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-14000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-14000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-14000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-14000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-12500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-14500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-14500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-14500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-14500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-13000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-15000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-15000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-15000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-15000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-13500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-15500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-15500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-15500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-15500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-15500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-14000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-16000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-16000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-16000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-16000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-14500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-16500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-16500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-16500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-16500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-16500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-15000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-17000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-17000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-17000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-17000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-17000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-15500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-17500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-17500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-17500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-17500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-16000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-18000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-18000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-18000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-18000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-16500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-18500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-18500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-18500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-18500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-18500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-18500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-17000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-19000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-19000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-19000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-19000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-19000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-17500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-19500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-19500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-19500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-19500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-19500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-19500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-18000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-20000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-20000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-20000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-20000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-18500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-20500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-20500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-20500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-20500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-20500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-20500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-19000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-21000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-21000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-21000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-21000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-21000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-21000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-19500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-21500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-21500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-21500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-21500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-21500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-21500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-20000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-22000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-22000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-22000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-22000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-22000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-22000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-20500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-22500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-22500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-22500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-22500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-22500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-22500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-21000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-23000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-23000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-23000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-23000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-23000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-23000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-21500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-23500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-23500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-23500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-23500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-23500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-23500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-22000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-24000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-24000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-24000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-24000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-24000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-24000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-22500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-24500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-24500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-24500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-24500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-24500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-24500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-23000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-25000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-25000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-25000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-25000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-25000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-25000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-23500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-25500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-25500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-25500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-25500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-25500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-25500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-24000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-26000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-26000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-26000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-26000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-26000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-26000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-24500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-26500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-26500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-26500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-26500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-26500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-26500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-25000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-27000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-27000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-27000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-27000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-27000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-27000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-25500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-27500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-27500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-27500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-27500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-27500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-27500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-26000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-28000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-28000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-28000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-28000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-28000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-28000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-26500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-28500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-28500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-28500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-28500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-28500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-28500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-27000] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-29000
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-29000/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-29000/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-29000/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-29000/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-29000/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-27500] due to args.save_total_limit
# Saving model checkpoint to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-29500
# Configuration saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-29500/config.json
# Model weights saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-29500/pytorch_model.bin
# tokenizer config file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-29500/tokenizer_config.json
# Special tokens file saved in /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-29500/special_tokens_map.json
# Copy vocab file to /content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-29500/spiece.model
# Deleting older checkpoint [/content/gdrive/MyDrive/result/new-t5base-finetuned-pubmed/checkpoint-28000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: article, abstract.
# ***** Running Evaluation *****
#   Num examples = 6633
#   Batch size = 4
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=29981, training_loss=0.05502376236395029, metrics={'train_runtime': 17131.1848, 'train_samples_per_second': 7.0, 'train_steps_per_second': 1.75, 'total_flos': 1.6431449865191424e+17, 'train_loss': 0.05502376236395029, 'epoch': 1.0})

# %%
tokenized_datasets["test"][1:10]

# %%
#trainer.evaluate()
outputs = trainer.predict(tokenized_datasets["test"])
output_str = tokenizer.batch_decode(outputs[0], skip_special_tokens=True)
raw_datasets["test"].to_csv(result+"/test.csv")
pd.DataFrame(output_str).to_csv(result+"/pred.csv")
